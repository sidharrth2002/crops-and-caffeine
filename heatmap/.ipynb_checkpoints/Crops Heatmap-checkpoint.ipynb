# %%
import geopandas as gpd
import numpy as np
import pandas as pd
shapefile = 'worldMapData/ne_110m_admin_0_countries.shp'

# %%
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]
gdf.columns = ['country', 'country_code', 'geometry']
gdf = gdf.drop(gdf.index[159])
gdf.head()
# Out:
#                        country country_code  \
# 0                         Fiji          FJI
# 1  United Republic of Tanzania          TZA
# 2               Western Sahara          SAH
# 3                       Canada          CAN
# 4     United States of America          USA
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
cropsRaw = pd.read_csv('cropMainData/ProductionCropsEAllDataNOFLAG.csv')
cropsRaw.fillna(0, inplace=True)
cropsRaw.head()
# Out:
#    Area Code         Area  Item Code                              Item  \
# 0          2  Afghanistan        221               Almonds, with shell
# 1          2  Afghanistan        221               Almonds, with shell
# 2          2  Afghanistan        221               Almonds, with shell
# 3          2  Afghanistan        711  Anise, badian, fennel, coriander
# 4          2  Afghanistan        711  Anise, badian, fennel, coriander
#
#    Element Code         Element    Unit  Y1961  Y1962  Y1963  ...    Y2009  \
# 0          5312  Area harvested      ha    0.0    0.0    0.0  ...  11029.0
# 1          5419           Yield   hg/ha    0.0    0.0    0.0  ...  39154.0
# 2          5510      Production  tonnes    0.0    0.0    0.0  ...  43183.0
# 3          5312  Area harvested      ha    0.0    0.0    0.0  ...  17748.0
# 4          5419           Yield   hg/ha    0.0    0.0    0.0  ...   6203.0
#
#      Y2010    Y2011    Y2012    Y2013    Y2014    Y2015    Y2016    Y2017  \
# ...

# %%
cropsRaw.groupby('Area').sum().loc[:,'Y1961':]
# Out:
#                        Y1961         Y1962         Y1963         Y1964  \
# Area
# Afghanistan     2.000653e+07  2.049832e+07  2.015797e+07  2.109285e+07
# Africa          6.365208e+08  6.691019e+08  7.013497e+08  7.003203e+08
# Albania         3.553615e+06  3.528621e+06  3.520732e+06  4.174251e+06
# Algeria         1.810245e+07  2.117536e+07  2.125603e+07  1.883706e+07
# American Samoa  5.404300e+05  5.489240e+05  5.628530e+05  5.713720e+05
# ...                      ...           ...           ...           ...
# World           7.494897e+09  7.645629e+09  7.806219e+09  8.214200e+09
# Yemen           6.406697e+06  6.559481e+06  6.772672e+06  6.836195e+06
# Yugoslav SFR    5.482893e+07  5.650976e+07  6.174567e+07  6.411953e+07
# Zambia          5.684375e+06  5.708020e+06  5.670612e+06  5.884616e+06
# Zimbabwe        1.024762e+07  1.134685e+07  1.067763e+07  1.241264e+07
#
#                        Y1965         Y1966         Y1967         Y1968  \
# Area
# ...
