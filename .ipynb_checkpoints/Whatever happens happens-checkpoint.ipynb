# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
main = pd.read_csv('cropMainData/ProductionCropsEAllDataNOFLAG.csv', encoding = "ISO-8859-1")

caffeine = main[main['Item'].str.contains('Coffee|Tea|Cocoa|Kola')]

# caffeine.groupby('Area').mean()
caffeineInAfrica = main[np.logical_and(main['Area']=='World', main['Item'].str.contains('Coffee|Tea|Cocoa|Kola'))][main['Element']=='Production']
caffeineInAfrica.index = caffeineInAfrica['Item']
caffeineInAfrica.loc[:, 'Y1961':].plot(kind='bar', legend=False)
caffeineInAfrica
# caffeineInAfrica[caffeineInAfrica['Item']=='Coffee, green'].loc[:, 'Y1961':].idxmax(axis=1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                Area Code   Area  Item Code           Item  Element Code  \
# Item
# Cocoa, beans        5000  World        661   Cocoa, beans          5510
# Coffee, green       5000  World        656  Coffee, green          5510
# Kola nuts           5000  World        224      Kola nuts          5510
# Tea                 5000  World        667            Tea          5510
#
#                   Element    Unit      Y1961      Y1962      Y1963  ...  \
# Item                                                                ...
# Cocoa, beans   Production  tonnes  1186364.0  1213539.0  1280516.0  ...
# Coffee, green  Production  tonnes  4527876.0  4584371.0  4152127.0  ...
# Kola nuts      Production  tonnes   191500.0   193500.0   197500.0  ...
# Tea            Production  tonnes   983785.0   987350.0  1021949.0  ...
#
# ...
